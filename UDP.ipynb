# %% [markdown]
# <a href="https://colab.research.google.com/github/HyacinthSchatten/UDA/blob/main/UDP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/HyacinthSchatten/Deep-Unsupervised-Domain-Adaptation
# Out:
# Cloning into 'Deep-Unsupervised-Domain-Adaptation'...
# remote: Enumerating objects: 773, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 773 (delta 53), reused 19 (delta 5), pack-reused 679
# Receiving objects: 100% (773/773), 126.05 MiB | 35.50 MiB/s, done.
# Resolving deltas: 100% (357/357), done.

# %%
# %cd /content/Deep-Unsupervised-Domain-Adaptation/DeepCORAL
# Out:
# /content/Deep-Unsupervised-Domain-Adaptation/DeepCORAL

# %%
# !wget https://wjdcloud.blob.core.windows.net/dataset/OFFICE31.zip

# %%
# !unzip OFFICE31.zip

# %%
# !python main.py --epochs 100 --batch_size_source 128 --batch_size_target 128 --name_source amazon --name_target webcam
# Out:
# creating source/target dataloaders...
# source data: amazon
# target data: webcam
# using cuda...
# loading pre-trained AlexNet...
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-4df8aa71.pth
# 100% 233M/233M [00:01<00:00, 129MB/s]
# loaded model correctly...
# model type: <class 'model.DeepCORAL'>
# adapt domain: False
# running training for 100 epochs...
# ...
#   0%|          | 0/6 [00:00<?, ?it/s]
# CUDA: True
# compute covariance bath size n: 128
# compute covariance bath size n: 128
# Train Epoch:  1 [ 1/ 6]	Lambda value: 0.0000, Classification loss: 3.542932, CORAL loss: 0.000007, Total_Loss: 3.542932
# CUDA: True
# compute covariance bath size n: 128
# compute covariance bath size n: 128
# Train Epoch:  1 [ 2/ 6]	Lambda value: 0.0000, Classification loss: 3.213726, CORAL loss: 0.000011, Total_Loss: 3.213726
# CUDA: True
# compute covariance bath size n: 128
# compute covariance bath size n: 128
# ...

# %%
# !python plot_loss_acc.py --source amazon --target webcam --no_epochs 10
# Out:
# folder with pkl data does not exist, must train model
